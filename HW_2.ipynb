# %% [markdown]
# <a href="https://colab.research.google.com/github/salamshakur/CAP4630-Artificial-Intelligence-UCF/blob/master/HW_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Libraries

# %%
from mpl_toolkits import mplot3d

# %%
# %matplotlib inline
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Problem 1 where {
# p1 = (0,0),
# p2 = (0,0),
# p3 = (0,0)
# }

# %%
def f_1(x,y):
  return np.sqrt(x**2 + y**2)

x = np.linspace(-10,10,50)
y = np.linspace(-10,10,50)

X, Y = np.meshgrid(x,y)
Z = f_1(X,Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 500, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.scatter(0, 0, 0, color = 'red')
ax.text(0, 0, 0, "Minimum", color = 'red')
#ax.view_init(40,120)
# Out:
# Text(0, 0, 'Minimum')

# %%
def f_2(x,y):
  return (np.sqrt(x**2 + y**2)) * (-1)

x = np.linspace(-10,10,50)
y = np.linspace(-10,10,50)

X, Y = np.meshgrid(x,y)
Z = f_2(X,Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 500, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.scatter(0, 0, 0, color = 'red')
ax.text(0, 0, 0, "Maximum", color = 'red')
#ax.view_init(40,120)
# Out:
# Text(0, 0, 'Maximum')

# %%
def f_3(x,y):
  return (x**2) - (y**2)

x = np.linspace(-10,10,50)
y = np.linspace(-10,10,50)

X, Y = np.meshgrid(x,y)
Z = f_3(X,Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 500, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.scatter(0, 0, 0, color = 'red')
ax.text(0, 0, 0, "Saddle Point", color = 'red')
#ax.view_init(40,120)

# %% [markdown]
# Problem 2 - Implementing two weights

# %%
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

m = 100
X1 = 2 * np.random.rand(m, 1)
X2 = 2 * np.random.rand(m, 1)
Y = 4 + 3 * X1 + np.random.rand(m, 1)

X_b = np.column_stack([np.ones((m, 1)), X])
X_new = np.array([[0], [2]])
X_new_b = np.column_stack([np.ones((2, 1)), X_new])

epochs = 20
lr = 0.01

np.random.seed(42)
initial_weight = np.random.randn(3, 1)

X_b = np.column_stack([np.ones((m,1)), X1, X2])

weight = initial_weight
weight_path_mgd = []
batch_size = 4

weight_path_mgd.append(weight)

for epoch in range(epochs):
    shuffled_indices = np.random.permutation(m)
    X_b_shuffled = X_b[shuffled_indices]
    y_shuffled = y[shuffled_indices]
    for i in range(0, m, batch_size):
        xi = X_b_shuffled[i:i+batch_size]
        yi = y_shuffled[i:i+batch_size]
        gradient = 1 / batch_size * xi.T.dot(xi.dot(weight) - yi)
        weight = weight - lr * gradient
        weight_path_mgd.append(weight)

weight_path_mgd = np.array(weight_path_mgd)
fig = plt.figure(figsize=(6,6))
ax = plt.axes(projection='3d')
ax.set_xlabel('w_0')
ax.set_ylabel('w_1')
ax.set_zlabel('w_2')
ax.scatter(weight_path_mgd[:, 0], weight_path_mgd[:, 1], weight_path_mgd[:, 2], color="green", alpha=0.2)

# %% [markdown]
# Problem 3 - Average MSINT for each digit in training set

# %%
# %tensorflow_version 2.x
import tensorflow as tf

(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

# %%
stats = []

for i in range(0, 10):
    stats.append(0)

# %%
for i in train_labels:
  stats[i] += 1

total = len(train_images)

print('Average MSINT of each digit')
for i in range(0, len(stats)):
  x = (stats[i]/total) * 100
  print('Digit ', i , ' -> ' , x , '%')
# Out:
# Average MSINT of each digit
# Digit  0  ->  9.871666666666666 %
# Digit  1  ->  11.236666666666666 %
# Digit  2  ->  9.93 %
# Digit  3  ->  10.218333333333334 %
# Digit  4  ->  9.736666666666666 %
# Digit  5  ->  9.035 %
# Digit  6  ->  9.863333333333333 %
# Digit  7  ->  10.441666666666666 %
# Digit  8  ->  9.751666666666667 %
# Digit  9  ->  9.915000000000001 %
